# %% [markdown]
# In this repository, you will find JSON representing a <i>subset</i> of the data for the <a href="http://modeldb.yale.edu">ModelDB</a> repository of computational neuroscience models.

# %% [markdown]
# <h1>Getting started</h1>

# %% [markdown]
# Begin by cloning this repository. Create a private repository on github and push your local copy to there.<br/><br/>Connect to MongoDB and create a database for this assignment.

# %%
import pymongo
from pymongo import MongoClient
mongodb = MongoClient()   
hw1 = mongodb.hw1

# %% [markdown]
# Using the <tt>json</tt> module and Python file operations, load the data from <tt>modelcollection.json</tt> and <tt>papercollection.json</tt> into Python.

# %%
import json
x = open('modelcollection.json')
y = open('papercollection.json')
model_data = json.load(x)
paper_data = json.load(y)

# %% [markdown]
# Put the loaded data into two collections in your database. I recommend calling them <tt>models</tt> and <tt>papers</tt>.

# %%
models = hw1.models
models.insert_many(model_data)
papers = hw1.papers
papers.insert_many(paper_data)

# %% [markdown]
# <h1>Explore the database</h1>

# %% [markdown]
# Use MongoDB to answer the following questions. Run your code in the spaces provided.

# %% [markdown]
# <b>Q: How many models are there?</b>

# %%
models.count()
# Out:
# 1114

# %% [markdown]
# <b>What are the field names (keys) for the model entry with <tt>_id</tt> = 87284?</b>

# %%
document = hw1.papers.find_one()
pprint.pprint(document)
# Out:
# {u'_id': 3860,
#  u'authors': [u'Crane GJ', u'Hines ML', u'Neild TO'],
#  u'doi': u'10.1111/j.1549-8719.2001.tb00156.x',
#  u'first_page': u'33',
#  u'journal': u'Microcirculation',
#  u'last_page': u'43',
#  u'missing_references': u'all done',
#  u'month': u'Feb',
#  u'pubmed_id': u'11296851',
#  u'references': [4461,
#                  4755,
#                  4757,
#                  4758,
#                  4764,
#                  4770,
#                  4773,
#                  4777,
#                  4781,
#                  4782,
#                  4786,
#                  4790,
#                  4792,
#                  4793,
#                  4797,
#                  4799,
#                  4800,
#                  4805,
#                  4806,
#                  4810,
#                  4815,
#                  4818,
#                  4819,
#                  4820,
#                  4823,
#                  4825,
#                  17148,
#                  17150,
#                  17152,
#                  17154,
#                  86943],
#  u'title': u'Simulating the spread of membrane potential changes in arteriolar networks.',
#  u'type': u'M',
#  u'volume': u'8',
#  u'year': u'2001'}

# %%
import pprint
doc = models.find_one({"_id": 87284})
pprint.pprint(doc.keys())
# Out:
# [u'transmitters',
#  u'title',
#  u'text',
#  u'genes',
#  u'simenvironment',
#  u'celltypes',
#  u'brainregions',
#  u'channels',
#  u'references',
#  u'modeltype',
#  u'receptors',
#  u'_id',
#  u'modelconcepts']

# %% [markdown]
# Note: this data is not completely denormalized: references in both collections are given in terms of the <tt>_id</tt> field of the paper collection.<br/><br/><b>How many distinct cell types are in the models collection?</b>

# %%
 models.find().distinct('celltypes')
# Out:
# [u'Substantia nigra pars compacta dopaminergic cell',
#  u'Hippocampus CA3 pyramidal cell',
#  u'Leech S cell',
#  u'Hippocampus CA1 interneuron oriens alveus',
#  u'Heart cell',
#  u'Globus pallidus neuron',
#  u'Skeletal muscle cell',
#  u'Hippocampus CA1 pyramidal cell',
#  u'Neocortex layer 5-6 pyramidal cell',
#  u'Thalamus geniculate nucleus (lateral) principal neuron',
#  u'Thalamus reticular nucleus cell',
#  u'Neuroblastoma',
#  u'Hippocampus dissociated neuron',
#  u'Leech heart interneuron',
#  u'Squid axon',
#  u'Astrocyte',
#  u'Cerebellum golgi cell',
#  u'Nucleus accumbens spiny projection neuron',
#  u'Neocortex layer 2-3 pyramidal cell',
#  u'Cerebellum purkinje cell',
#  u'Medial Nucleus of the Trapezoid Body (MNTB) neuron',
#  u'GnRH neuron',
#  u'Abstract Wang-Buzsaki neuron',
#  u'Hippocampus CA1 basket cell',
#  u'NG108-15 neuronal cell',
#  u'Abstract integrate-and-fire adaptive exponential (AdEx) neuron',
#  u'Spinal cord motor neuron',
#  u'Spinal lamprey neuron',
#  u'Neocortex spiny stellate cell',
#  u'Olfactory bulb main interneuron granule MC cell',
#  u'Olfactory bulb main mitral cell',
#  u'Hodgkin-Huxley neuron',
#  u'Abstract Morris-Lecar neuron',
#  u'Leech C interneuron',
#  u'Aplysia B31/B32 neuron',
#  u'Dentate gyrus granule cell',
#  u'Cerebellum interneuron granule cell',
#  u'Subthalamus nucleus projection neuron',
#  u'Electric fish midbrain torus semicircularis neuron',
#  u'Locust Lobula Giant Movement Detector (LGMD) neuron',
#  u'Fly lobular plate vertical system cell',
#  u'Crab Stomatogastric Ganglion (STG) Lateral Pyloric (LP) cell',
#  u'Spinal cord Ia interneuron',
#  u'Spinal cord Ib interneuron',
#  u'Spinal cord motor neuron fast fatiguing',
#  u'Spinal cord motor neuron fatigue resistant',
#  u'Spinal cord motor neuron slow twitch',
#  u'Spinal cord renshaw cell',
#  u'Stick insect nonspiking interneuron',
#  u'Neostriatum fast spiking interneuron',
#  u'Drosophila antennal lobe DM1 projection neuron',
#  u'Auditory nerve',
#  u'Cardiac ventricular cell',
#  u'Leech Retzius neuron',
#  u'Myelinated neuron',
#  u'Neocortex fast spiking (FS) interneuron',
#  u'Neocortex spiking low threshold (LTS) neuron',
#  u'Neocortex spiking regular (RS) neuron',
#  u'Dentate gyrus basket cell',
#  u'Dentate gyrus hilar cell',
#  u'Dentate gyrus mossy cell',
#  u'Abstract integrate-and-fire leaky neuron',
#  u'Retina bipolar cell',
#  u'Retina ganglion cell',
#  u'Retina photoreceptor cone cell',
#  u'Neostriatum spiny direct pathway neuron',
#  u'Dentate gyrus MOPP cell',
#  u'Respiratory column neuron',
#  u'Helix pacemaker bursting neuron (RPa1)',
#  u'Cochlea hair cell (auditory)',
#  u'CN stellate cell',
#  u'Cochlear nucleus bushy cell',
#  u'Vibrissa motoneuron',
#  u'C elegans Hermaphrodite-Specific neuron (HSN)',
#  u'C elegans VC motor neuron',
#  u'C elegans uterine-vulval cell (uv1)',
#  u'Vibrissa motor plant',
#  u'Neocortex dissociated cultured nerve cell',
#  u'Wide dynamic range neuron',
#  u'Entorhinal cortex stellate cell',
#  u'Neocortex interneuron basket cell',
#  u'Olfactory receptor neuron',
#  u'Cerebellum deep nucleus neuron',
#  u'Hippocampus CA1 stratum radiatum interneuron',
#  u'Dorsal root ganglion (DRG) cell',
#  u'Hippocampus CA3 basket cell',
#  u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#  u'Vestibular neuron',
#  u'Superior paraolivary nucleus neuron',
#  u'Thalamus lateral geniculate nucleus interneuron',
#  u'Olfactory bulb main interneuron periglomerular cell',
#  u'Olfactory bulb main juxtaglomerular cell',
#  u'ELL pyramidal cell',
#  u'Hippocampus CA3 stratum radiatum lacunosum-moleculare interneuron',
#  u'Cardiac atrial cell',
#  u'Medial Superior Olive (MSO) cell',
#  u'Hippocampus septum medial GABAergic neuron',
#  u'Lateral Superior Olive (LSO) cell',
#  u'Stomatogastric ganglion pyloric dilator neuron',
#  u'Stomatogastric ganglion pyloric neuron',
#  u'Inferior olive neuron',
#  u'Thalamus DLM projection neuron',
#  u'Locus Coeruleus neuron',
#  u'Suprachiasmatic nucleus (SCN) neuron',
#  u'Abstract theta neuron',
#  u'Olfactory cortex anterior interneuron deep layer',
#  u'Olfactory cortex anterior interneuron superficial layer',
#  u'Olfactory cortex anterior pyramidal neuron',
#  u'Neocortex bitufted interneuron',
#  u'Aplysia sensory neuron',
#  u'Neocortical pyramidal intra-telencephalic cell',
#  u'Neocortical pyramidal tract cortical-spinal cell',
#  u'Neostriatum spiny indirect pathway neuron',
#  u'Neostriatum spiny neuron',
#  u'Substantia nigra pars reticulata principal cell',
#  u'Cochlear nucleus pyramidal (fusiform) cell',
#  u'Crayfish motor neuron',
#  u'Neocortex deep neurogliaform interneuron',
#  u'Neocortex superficial neurogliaform interneuron',
#  u'Spinal cord sympathetic preganglionic neuron',
#  u'Ventral cochlear nucleus T stellate (chopper) neuron',
#  u'Grueneberg ganglion neuron',
#  u'Olfactory bulb main interneuron granule TC cell',
#  u'Aplysia motor neuron',
#  u'Leech heart motor neuron (HE)',
#  u'Abstract Izhikevich neuron',
#  u'Pituitary cell',
#  u'Fly vertical system tangential cell',
#  u'Gastrointestinal tract intrinsic sensory neuron',
#  u'Abstract integrate-and-fire fractional leaky neuron',
#  u'Abstract single compartment conductance based cell',
#  u'Neocortex spiking irregular interneuron',
#  u'Olfactory bulb main tufted middle cell',
#  u'Olfactory bulb short axon cell',
#  u'Fly lamina neuron',
#  u'Fly medulla neuron',
#  u'Macrophage',
#  u'Microglia',
#  u'Hippocampus CA1 axo-axonic cell',
#  u'Hippocampus CA1 bistratified cell',
#  u'Hippocampus CA3 axo-axonic cells',
#  u'Hippocampus CA1 stratum oriens lacunosum-moleculare interneuron ',
#  u'Hippocampus CA1 PV+ fast-firing interneuron',
#  u'Dorsal Root Ganglion cell: cold sensing',
#  u'Neocortex layer 4 pyramidal cell',
#  u'Neocortex layer 6a interneuron',
#  u'Neocortex layer 5 interneuron',
#  u'Neocortex layer 2-3 interneuron',
#  u'Neocortex layer 4 interneuron',
#  u'Crab Stomatogastric Ganglion (STG) Lateral Gastric (LG) cell',
#  u'Brainstem neuron',
#  u'Neocortex layer 4 neuron',
#  u'Olfactory bulb (accessory) mitral cell',
#  u'Neocortical pyramidal cortical-thalamic cell',
#  u'Teleost thalamic neuron',
#  u'Abstract Hindmarsh-Rose neuron',
#  u'Pinsky-Rinzel CA1/3 pyramidal cell ',
#  u'Cochlear nucleus octopus cell',
#  u'Hermissenda photoreceptor Type B',
#  u'Nucleus laminaris neuron',
#  u'Aplysia cultured neuron',
#  u'Honeybee kenyon cell',
#  u'Aplysia interneuron',
#  u'Crab Stomatogastric Ganglion (STG) Modulatory commissural neuron 1 (MCN1)',
#  u'Crab Stomatogastric Ganglion (STG) interneuron 1 (Int1)',
#  u'Arteriolar network',
#  u'Leech pressure (P) mechanosensory neuron',
#  u'Leech T segmental sensory neuron',
#  u'Depressor scutorum rostralis muscle cell',
#  u'Aplysia R15 bursting neuron',
#  u'Spinal cord lamina I neuron',
#  u'Cochlear ganglion cell Type II',
#  u'Aplysia feeding CPG neurons',
#  u'Hermissenda photoreceptor Type A',
#  u'Electric fish P- and T-type primary afferent fibers',
#  u'Crayfish identified nonspiking interneuron',
#  u'Intramuscular interstitial cell of Cajal (ICCIM)',
#  u'Myenteric interstitial cell of Cajal (ICCMY)',
#  u'Tritonia cerebral cell',
#  u'Tritonia swim interneuron dorsal',
#  u'Tritonia swim interneuron ventral',
#  u'Turtle dorsal cortex horizontal cell',
#  u'Turtle dorsal cortex lateral pyramidal cell',
#  u'Turtle dorsal cortex medial pyramidal cell',
#  u'Turtle dorsal cortex stellate cell',
#  u'Turtle dorsal cortex subpial cell',
#  u'B lymphocyte',
#  u'Neostriatum interneuron cholinergic cell']

# %% [markdown]
# <b>Find the list of model ids for models that contain a Hippocampus CA3 pyramidal cell.</b>

# %%
for doc in models.find({"celltypes": "Hippocampus CA3 pyramidal cell"}, {"_id":1}):
    pprint.pprint(doc)
# Out:
# {u'_id': 101629}
# {u'_id': 114337}
# {u'_id': 118098}
# {u'_id': 120907}
# {u'_id': 126814}
# {u'_id': 129067}
# {u'_id': 135902}
# {u'_id': 135903}
# {u'_id': 137259}
# {u'_id': 137505}
# {u'_id': 138421}
# {u'_id': 139421}
# {u'_id': 142104}
# {u'_id': 143148}
# {u'_id': 146499}
# {u'_id': 147756}
# {u'_id': 147867}
# {u'_id': 148035}
# {u'_id': 150288}
# {u'_id': 151282}
# {u'_id': 168314}
# {u'_id': 168874}
# {u'_id': 181967}
# {u'_id': 184139}
# {u'_id': 185512}
# {u'_id': 186768}
# {u'_id': 189088}
# {u'_id': 20007}
# {u'_id': 3263}
# {u'_id': 35358}
# {u'_id': 7907}
# {u'_id': 84606}
# {u'_id': 87216}
# {u'_id': 87762}
# {u'_id': 98003}

# %% [markdown]
# <b>What other cells appear in models with a Hippocampus CA3 pyramidal cell? Sort them in alphabetical order. How many such cells are there?</b>

# %%
for doc in models.find({"celltypes": "Hippocampus CA3 pyramidal cell"}):
    results.append(doc["celltypes"])

results.sort()

pprint.pprint(results)
# Out:
# [[u'Dentate gyrus granule cell',
#   u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Dentate gyrus mossy cell',
#   u'Dentate gyrus basket cell',
#   u'Dentate gyrus hilar cell',
#   u'Hippocampus CA1 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Hippocampus CA1 bistratified cell',
#   u'Hippocampus CA1 axo-axonic cell',
#   u'Hippocampus CA3 axo-axonic cells'],
#  [u'Dentate gyrus granule cell',
#   u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Dentate gyrus mossy cell',
#   u'Dentate gyrus basket cell',
#   u'Dentate gyrus hilar cell',
#   u'Hippocampus CA1 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Hippocampus CA1 bistratified cell',
#   u'Hippocampus CA1 axo-axonic cell',
#   u'Hippocampus CA3 axo-axonic cells'],
#  [u'Dentate gyrus granule cell',
#   u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Dentate gyrus mossy cell',
#   u'Dentate gyrus basket cell',
#   u'Dentate gyrus hilar cell',
#   u'Hippocampus CA1 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Hippocampus CA1 bistratified cell',
#   u'Hippocampus CA1 axo-axonic cell',
#   u'Hippocampus CA3 axo-axonic cells'],
#  [u'Dentate gyrus granule cell',
#   u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Dentate gyrus mossy cell',
#   u'Dentate gyrus basket cell',
#   u'Dentate gyrus hilar cell',
#   u'Hippocampus CA1 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Hippocampus CA1 bistratified cell',
#   u'Hippocampus CA1 axo-axonic cell',
#   u'Hippocampus CA3 axo-axonic cells'],
#  [u'Dentate gyrus granule cell',
#   u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Dentate gyrus mossy cell',
#   u'Dentate gyrus basket cell',
#   u'Dentate gyrus hilar cell',
#   u'Hippocampus CA1 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Hippocampus CA1 bistratified cell',
#   u'Hippocampus CA1 axo-axonic cell',
#   u'Hippocampus CA3 axo-axonic cells'],
#  [u'Dentate gyrus granule cell',
#   u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Dentate gyrus mossy cell',
#   u'Dentate gyrus basket cell',
#   u'Dentate gyrus hilar cell',
#   u'Hippocampus CA1 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Hippocampus CA1 bistratified cell',
#   u'Hippocampus CA1 axo-axonic cell',
#   u'Hippocampus CA3 axo-axonic cells'],
#  [u'Dentate gyrus granule cell',
#   u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Dentate gyrus mossy cell',
#   u'Dentate gyrus basket cell',
#   u'Dentate gyrus hilar cell',
#   u'Hippocampus CA1 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Hippocampus CA1 bistratified cell',
#   u'Hippocampus CA1 axo-axonic cell',
#   u'Hippocampus CA3 axo-axonic cells'],
#  [u'Dentate gyrus granule cell',
#   u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Dentate gyrus mossy cell',
#   u'Dentate gyrus basket cell',
#   u'Dentate gyrus hilar cell',
#   u'Hippocampus CA1 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Hippocampus CA1 bistratified cell',
#   u'Hippocampus CA1 axo-axonic cell',
#   u'Hippocampus CA3 axo-axonic cells'],
#  [u'Dentate gyrus granule cell',
#   u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Dentate gyrus mossy cell',
#   u'Dentate gyrus basket cell',
#   u'Dentate gyrus hilar cell',
#   u'Hippocampus CA1 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Hippocampus CA1 bistratified cell',
#   u'Hippocampus CA1 axo-axonic cell',
#   u'Hippocampus CA3 axo-axonic cells'],
#  [u'Dentate gyrus granule cell',
#   u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Dentate gyrus mossy cell',
#   u'Dentate gyrus basket cell',
#   u'Dentate gyrus hilar cell',
#   u'Hippocampus CA1 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Hippocampus CA1 bistratified cell',
#   u'Hippocampus CA1 axo-axonic cell',
#   u'Hippocampus CA3 axo-axonic cells'],
#  [u'Dentate gyrus granule cell',
#   u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Dentate gyrus mossy cell',
#   u'Dentate gyrus basket cell',
#   u'Dentate gyrus hilar cell',
#   u'Hippocampus CA1 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Hippocampus CA1 bistratified cell',
#   u'Hippocampus CA1 axo-axonic cell',
#   u'Hippocampus CA3 axo-axonic cells'],
#  [u'Dentate gyrus granule cell',
#   u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Dentate gyrus mossy cell',
#   u'Dentate gyrus basket cell',
#   u'Dentate gyrus hilar cell',
#   u'Hippocampus CA1 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Hippocampus CA1 bistratified cell',
#   u'Hippocampus CA1 axo-axonic cell',
#   u'Hippocampus CA3 axo-axonic cells'],
#  [u'Dentate gyrus granule cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Abstract Izhikevich neuron'],
#  [u'Dentate gyrus granule cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Abstract Izhikevich neuron'],
#  [u'Dentate gyrus granule cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Abstract Izhikevich neuron'],
#  [u'Dentate gyrus granule cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Abstract Izhikevich neuron'],
#  [u'Dentate gyrus granule cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Abstract Izhikevich neuron'],
#  [u'Dentate gyrus granule cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Abstract Izhikevich neuron'],
#  [u'Dentate gyrus granule cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Abstract Izhikevich neuron'],
#  [u'Dentate gyrus granule cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Abstract Izhikevich neuron'],
#  [u'Dentate gyrus granule cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Abstract Izhikevich neuron'],
#  [u'Dentate gyrus granule cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Abstract Izhikevich neuron'],
#  [u'Dentate gyrus granule cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Abstract Izhikevich neuron'],
#  [u'Dentate gyrus granule cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Abstract Izhikevich neuron'],
#  [u'Hippocampus CA1 pyramidal cell', u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell', u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell', u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell', u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell', u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell', u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell', u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell', u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell', u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell', u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell', u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell', u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell', u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell', u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell', u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell', u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell', u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell', u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell', u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell', u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell', u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell', u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell', u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell', u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Entorhinal cortex stellate cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Entorhinal cortex stellate cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Entorhinal cortex stellate cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Entorhinal cortex stellate cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Entorhinal cortex stellate cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Entorhinal cortex stellate cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Entorhinal cortex stellate cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Entorhinal cortex stellate cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Entorhinal cortex stellate cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Entorhinal cortex stellate cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Entorhinal cortex stellate cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Entorhinal cortex stellate cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Entorhinal cortex stellate cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Entorhinal cortex stellate cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Entorhinal cortex stellate cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Entorhinal cortex stellate cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Entorhinal cortex stellate cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Entorhinal cortex stellate cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Entorhinal cortex stellate cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Entorhinal cortex stellate cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Entorhinal cortex stellate cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Entorhinal cortex stellate cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Entorhinal cortex stellate cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Entorhinal cortex stellate cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Hippocampus CA1 basket cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Hippocampus CA1 basket cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Hippocampus CA1 basket cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Hippocampus CA1 basket cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Hippocampus CA1 basket cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Hippocampus CA1 basket cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Hippocampus CA1 basket cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Hippocampus CA1 basket cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Hippocampus CA1 basket cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Hippocampus CA1 basket cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Hippocampus CA1 basket cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Hippocampus CA1 basket cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Hippocampus CA1 basket cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Hippocampus CA1 basket cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Hippocampus CA1 basket cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Hippocampus CA1 basket cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Hippocampus CA1 basket cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Hippocampus CA1 basket cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Hippocampus CA1 basket cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Hippocampus CA1 basket cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Hippocampus CA1 basket cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Hippocampus CA1 basket cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Hippocampus CA1 basket cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Hippocampus CA1 basket cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Neocortex fast spiking (FS) interneuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Neocortex fast spiking (FS) interneuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Neocortex fast spiking (FS) interneuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Neocortex fast spiking (FS) interneuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Neocortex fast spiking (FS) interneuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Neocortex fast spiking (FS) interneuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Neocortex fast spiking (FS) interneuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Neocortex fast spiking (FS) interneuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Neocortex fast spiking (FS) interneuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Neocortex fast spiking (FS) interneuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Neocortex fast spiking (FS) interneuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA1 interneuron oriens alveus',
#   u'Neocortex fast spiking (FS) interneuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hodgkin-Huxley neuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hodgkin-Huxley neuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hodgkin-Huxley neuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hodgkin-Huxley neuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hodgkin-Huxley neuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hodgkin-Huxley neuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hodgkin-Huxley neuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hodgkin-Huxley neuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hodgkin-Huxley neuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hodgkin-Huxley neuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hodgkin-Huxley neuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Hodgkin-Huxley neuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex fast spiking (FS) interneuron',
#   u'Neocortex spiking regular (RS) neuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex fast spiking (FS) interneuron',
#   u'Neocortex spiking regular (RS) neuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex fast spiking (FS) interneuron',
#   u'Neocortex spiking regular (RS) neuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex fast spiking (FS) interneuron',
#   u'Neocortex spiking regular (RS) neuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex fast spiking (FS) interneuron',
#   u'Neocortex spiking regular (RS) neuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex fast spiking (FS) interneuron',
#   u'Neocortex spiking regular (RS) neuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex fast spiking (FS) interneuron',
#   u'Neocortex spiking regular (RS) neuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex fast spiking (FS) interneuron',
#   u'Neocortex spiking regular (RS) neuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex fast spiking (FS) interneuron',
#   u'Neocortex spiking regular (RS) neuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex fast spiking (FS) interneuron',
#   u'Neocortex spiking regular (RS) neuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex fast spiking (FS) interneuron',
#   u'Neocortex spiking regular (RS) neuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex fast spiking (FS) interneuron',
#   u'Neocortex spiking regular (RS) neuron'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Cerebellum purkinje cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Cerebellum purkinje cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Cerebellum purkinje cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Cerebellum purkinje cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Cerebellum purkinje cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Cerebellum purkinje cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Cerebellum purkinje cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Cerebellum purkinje cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Cerebellum purkinje cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Cerebellum purkinje cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Cerebellum purkinje cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Cerebellum purkinje cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Neocortex layer 2-3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Neocortex layer 2-3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Neocortex layer 2-3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Neocortex layer 2-3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Neocortex layer 2-3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Neocortex layer 2-3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Neocortex layer 2-3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Neocortex layer 2-3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Neocortex layer 2-3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Neocortex layer 2-3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Neocortex layer 2-3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Neocortex layer 2-3 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Neocortex layer 2-3 pyramidal cell',
#   u'Neocortical pyramidal cortical-thalamic cell',
#   u'Neocortex layer 4 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Neocortex layer 2-3 pyramidal cell',
#   u'Neocortical pyramidal cortical-thalamic cell',
#   u'Neocortex layer 4 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Neocortex layer 2-3 pyramidal cell',
#   u'Neocortical pyramidal cortical-thalamic cell',
#   u'Neocortex layer 4 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Neocortex layer 2-3 pyramidal cell',
#   u'Neocortical pyramidal cortical-thalamic cell',
#   u'Neocortex layer 4 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Neocortex layer 2-3 pyramidal cell',
#   u'Neocortical pyramidal cortical-thalamic cell',
#   u'Neocortex layer 4 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Neocortex layer 2-3 pyramidal cell',
#   u'Neocortical pyramidal cortical-thalamic cell',
#   u'Neocortex layer 4 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Neocortex layer 2-3 pyramidal cell',
#   u'Neocortical pyramidal cortical-thalamic cell',
#   u'Neocortex layer 4 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Neocortex layer 2-3 pyramidal cell',
#   u'Neocortical pyramidal cortical-thalamic cell',
#   u'Neocortex layer 4 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Neocortex layer 2-3 pyramidal cell',
#   u'Neocortical pyramidal cortical-thalamic cell',
#   u'Neocortex layer 4 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Neocortex layer 2-3 pyramidal cell',
#   u'Neocortical pyramidal cortical-thalamic cell',
#   u'Neocortex layer 4 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Neocortex layer 2-3 pyramidal cell',
#   u'Neocortical pyramidal cortical-thalamic cell',
#   u'Neocortex layer 4 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Neocortex layer 5-6 pyramidal cell',
#   u'Neocortex layer 2-3 pyramidal cell',
#   u'Neocortical pyramidal cortical-thalamic cell',
#   u'Neocortex layer 4 pyramidal cell'],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Pinsky-Rinzel CA1/3 pyramidal cell '],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Pinsky-Rinzel CA1/3 pyramidal cell '],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Pinsky-Rinzel CA1/3 pyramidal cell '],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Pinsky-Rinzel CA1/3 pyramidal cell '],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Pinsky-Rinzel CA1/3 pyramidal cell '],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Pinsky-Rinzel CA1/3 pyramidal cell '],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Pinsky-Rinzel CA1/3 pyramidal cell '],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Pinsky-Rinzel CA1/3 pyramidal cell '],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Pinsky-Rinzel CA1/3 pyramidal cell '],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Pinsky-Rinzel CA1/3 pyramidal cell '],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Pinsky-Rinzel CA1/3 pyramidal cell '],
#  [u'Hippocampus CA1 pyramidal cell',
#   u'Hippocampus CA3 pyramidal cell',
#   u'Pinsky-Rinzel CA1/3 pyramidal cell '],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Abstract integrate-and-fire adaptive exponential (AdEx) neuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Abstract integrate-and-fire adaptive exponential (AdEx) neuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Abstract integrate-and-fire adaptive exponential (AdEx) neuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Abstract integrate-and-fire adaptive exponential (AdEx) neuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Abstract integrate-and-fire adaptive exponential (AdEx) neuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Abstract integrate-and-fire adaptive exponential (AdEx) neuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Abstract integrate-and-fire adaptive exponential (AdEx) neuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Abstract integrate-and-fire adaptive exponential (AdEx) neuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Abstract integrate-and-fire adaptive exponential (AdEx) neuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Abstract integrate-and-fire adaptive exponential (AdEx) neuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Abstract integrate-and-fire adaptive exponential (AdEx) neuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Abstract integrate-and-fire adaptive exponential (AdEx) neuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Hippocampus septum medial GABAergic neuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Hippocampus septum medial GABAergic neuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Hippocampus septum medial GABAergic neuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Hippocampus septum medial GABAergic neuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Hippocampus septum medial GABAergic neuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Hippocampus septum medial GABAergic neuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Hippocampus septum medial GABAergic neuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Hippocampus septum medial GABAergic neuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Hippocampus septum medial GABAergic neuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Hippocampus septum medial GABAergic neuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Hippocampus septum medial GABAergic neuron'],
#  [u'Hippocampus CA3 pyramidal cell',
#   u'Hippocampus CA3 basket cell',
#   u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'Hippocampus septum medial GABAergic neuron']]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-230-4cc0a1812338> in <module>()
#       6
#       7 pprint.pprint(results)
# ----> 8 print count(results)
#       9
#      10
#
# NameError: name 'count' is not defined

# %% [markdown]
# <h1>Use aggregation</h1>

# %% [markdown]
# How many models are there for each cell type? Display the results in a formatted table, sorted from most commonly appearing cell type to least commonly appearing.

# %%
from bson.son import SON
query = [
            {
                '$unwind': '$celltypes'
            },
            {
                '$group': {
                    '_id': '$celltypes',
                    'count': {'$sum':1}
                }
            },
            {'$sort': SON([('count',-1)])},
    
            
        ]

pprint.pprint(list(hw1.models.aggregate(query)))
# Out:
# [{u'_id': u'Neocortex layer 5-6 pyramidal cell', u'count': 108},
#  {u'_id': u'Hippocampus CA1 pyramidal cell', u'count': 104},
#  {u'_id': u'Neocortex layer 2-3 pyramidal cell', u'count': 60},
#  {u'_id': u'Hippocampus CA3 pyramidal cell', u'count': 35},
#  {u'_id': u'Olfactory bulb main mitral cell', u'count': 30},
#  {u'_id': u'Neocortex fast spiking (FS) interneuron', u'count': 30},
#  {u'_id': u'Hodgkin-Huxley neuron', u'count': 29},
#  {u'_id': u'Thalamus geniculate nucleus (lateral) principal neuron',
#   u'count': 26},
#  {u'_id': u'Abstract integrate-and-fire leaky neuron', u'count': 25},
#  {u'_id': u'Dentate gyrus granule cell', u'count': 24},
#  {u'_id': u'Cerebellum purkinje cell', u'count': 24},
#  {u'_id': u'Neocortex spiking regular (RS) neuron', u'count': 22},
#  {u'_id': u'Neostriatum spiny direct pathway neuron', u'count': 22},
#  {u'_id': u'Neocortex spiking low threshold (LTS) neuron', u'count': 21},
#  {u'_id': u'Neocortex layer 4 pyramidal cell', u'count': 20},
#  {u'_id': u'Globus pallidus neuron', u'count': 19},
#  {u'_id': u'Olfactory bulb main interneuron granule MC cell', u'count': 19},
#  {u'_id': u'Myelinated neuron', u'count': 18},
#  {u'_id': u'Spinal cord motor neuron', u'count': 17},
#  {u'_id': u'Neocortex interneuron basket cell', u'count': 16},
#  {u'_id': u'Auditory nerve', u'count': 15},
#  {u'_id': u'Squid axon', u'count': 15},
#  {u'_id': u'Heart cell', u'count': 14},
#  {u'_id': u'Neocortex layer 5 interneuron', u'count': 14},
#  {u'_id': u'Retina ganglion cell', u'count': 14},
#  {u'_id': u'Thalamus reticular nucleus cell', u'count': 14},
#  {u'_id': u'Subthalamus nucleus projection neuron', u'count': 13},
#  {u'_id': u'Cardiac ventricular cell', u'count': 13},
#  {u'_id': u'Cerebellum interneuron granule cell', u'count': 13},
#  {u'_id': u'Dentate gyrus basket cell', u'count': 12},
#  {u'_id': u'Neocortex spiny stellate cell', u'count': 12},
#  {u'_id': u'Hippocampus CA1 basket cell', u'count': 11},
#  {u'_id': u'Abstract integrate-and-fire adaptive exponential (AdEx) neuron',
#   u'count': 11},
#  {u'_id': u'Abstract Morris-Lecar neuron', u'count': 11},
#  {u'_id': u'Abstract Wang-Buzsaki neuron', u'count': 10},
#  {u'_id': u'Olfactory receptor neuron', u'count': 9},
#  {u'_id': u'Abstract Izhikevich neuron', u'count': 9},
#  {u'_id': u'Neostriatum fast spiking interneuron', u'count': 9},
#  {u'_id': u'Hippocampus CA1 interneuron oriens alveus', u'count': 9},
#  {u'_id': u'Substantia nigra pars compacta dopaminergic cell', u'count': 9},
#  {u'_id': u'Pituitary cell', u'count': 8},
#  {u'_id': u'Hippocampus CA3 stratum oriens lacunosum-moleculare interneuron',
#   u'count': 8},
#  {u'_id': u'Cerebellum golgi cell', u'count': 8},
#  {u'_id': u'Dentate gyrus mossy cell', u'count': 8},
#  {u'_id': u'Dentate gyrus hilar cell', u'count': 8},
#  {u'_id': u'Neocortex layer 2-3 interneuron', u'count': 7},
#  {u'_id': u'Entorhinal cortex stellate cell', u'count': 7},
#  {u'_id': u'Cerebellum deep nucleus neuron', u'count': 7},
#  {u'_id': u'Cochlea hair cell (auditory)', u'count': 7},
#  {u'_id': u'Dorsal root ganglion (DRG) cell', u'count': 7},
#  {u'_id': u'Olfactory bulb main interneuron periglomerular cell', u'count': 7},
#  {u'_id': u'Abstract single compartment conductance based cell', u'count': 7},
#  {u'_id': u'Hippocampus CA3 basket cell', u'count': 6},
#  {u'_id': u'Neuroblastoma', u'count': 6},
#  {u'_id': u'Retina photoreceptor cone cell', u'count': 6},
#  {u'_id': u'Neocortex layer 6a interneuron', u'count': 6},
#  {u'_id': u'Aplysia sensory neuron', u'count': 6},
#  {u'_id': u'Neostriatum spiny indirect pathway neuron', u'count': 6},
#  {u'_id': u'Aplysia motor neuron', u'count': 4},
#  {u'_id': u'Neostriatum spiny neuron', u'count': 4},
#  {u'_id': u'Olfactory bulb main interneuron granule TC cell', u'count': 4},
#  {u'_id': u'Thalamus lateral geniculate nucleus interneuron', u'count': 4},
#  {u'_id': u'Astrocyte', u'count': 4},
#  {u'_id': u'CN stellate cell', u'count': 4},
#  {u'_id': u'Retina bipolar cell', u'count': 4},
#  {u'_id': u'Cardiac atrial cell', u'count': 4},
#  {u'_id': u'ELL pyramidal cell', u'count': 4},
#  {u'_id': u'Medial Nucleus of the Trapezoid Body (MNTB) neuron', u'count': 4},
#  {u'_id': u'Leech heart interneuron', u'count': 4},
#  {u'_id': u'Medial Superior Olive (MSO) cell', u'count': 4},
#  {u'_id': u'Wide dynamic range neuron', u'count': 4},
#  {u'_id': u'Suprachiasmatic nucleus (SCN) neuron', u'count': 3},
#  {u'_id': u'Vestibular neuron', u'count': 3},
#  {u'_id': u'Cochlear nucleus bushy cell', u'count': 3},
#  {u'_id': u'Respiratory column neuron', u'count': 3},
#  {u'_id': u'NG108-15 neuronal cell', u'count': 3},
#  {u'_id': u'Hermissenda photoreceptor Type B', u'count': 3},
#  {u'_id': u'Locust Lobula Giant Movement Detector (LGMD) neuron', u'count': 3},
#  {u'_id': u'Nucleus accumbens spiny projection neuron', u'count': 3},
#  {u'_id': u'Skeletal muscle cell', u'count': 3},
#  {u'_id': u'Leech S cell', u'count': 3},
#  {u'_id': u'Tritonia cerebral cell', u'count': 2},
#  {u'_id': u'Aplysia interneuron', u'count': 2},
#  {u'_id': u'Teleost thalamic neuron', u'count': 2},
#  {u'_id': u'Cochlear ganglion cell Type II', u'count': 2},
#  {u'_id': u'Brainstem neuron', u'count': 2},
#  {u'_id': u'Neocortex layer 4 interneuron', u'count': 2},
#  {u'_id': u'Hippocampus CA1 PV+ fast-firing interneuron', u'count': 2},
#  {u'_id': u'Macrophage', u'count': 2},
#  {u'_id': u'Microglia', u'count': 2},
#  {u'_id': u'Hippocampus CA1 bistratified cell', u'count': 2},
#  {u'_id': u'Ventral cochlear nucleus T stellate (chopper) neuron',
#   u'count': 2},
#  {u'_id': u'Cochlear nucleus pyramidal (fusiform) cell', u'count': 2},
#  {u'_id': u'Olfactory cortex anterior pyramidal neuron', u'count': 2},
#  {u'_id': u'Aplysia R15 bursting neuron', u'count': 2},
#  {u'_id': u'Stomatogastric ganglion pyloric neuron', u'count': 2},
#  {u'_id': u'Stomatogastric ganglion pyloric dilator neuron', u'count': 2},
#  {u'_id': u'Neocortex layer 4 neuron', u'count': 2},
#  {u'_id': u'Crab Stomatogastric Ganglion (STG) Lateral Pyloric (LP) cell',
#   u'count': 2},
#  {u'_id': u'Vibrissa motoneuron', u'count': 2},
#  {u'_id': u'Honeybee kenyon cell', u'count': 2},
#  {u'_id': u'Spinal cord motor neuron slow twitch', u'count': 2},
#  {u'_id': u'Tritonia swim interneuron dorsal', u'count': 2},
#  {u'_id': u'Crab Stomatogastric Ganglion (STG) Lateral Gastric (LG) cell',
#   u'count': 2},
#  {u'_id': u'Leech T segmental sensory neuron', u'count': 2},
#  {u'_id': u'Electric fish midbrain torus semicircularis neuron', u'count': 2},
#  {u'_id': u'Spinal lamprey neuron', u'count': 2},
#  {u'_id': u'Dentate gyrus MOPP cell', u'count': 2},
#  {u'_id': u'GnRH neuron', u'count': 2},
#  {u'_id': u'Neocortex bitufted interneuron', u'count': 2},
#  {u'_id': u'Tritonia swim interneuron ventral', u'count': 2},
#  {u'_id': u'Hippocampus CA1 axo-axonic cell', u'count': 2},
#  {u'_id': u'Abstract integrate-and-fire fractional leaky neuron', u'count': 2},
#  {u'_id': u'Neostriatum interneuron cholinergic cell', u'count': 1},
#  {u'_id': u'Turtle dorsal cortex subpial cell', u'count': 1},
#  {u'_id': u'Turtle dorsal cortex horizontal cell', u'count': 1},
#  {u'_id': u'Turtle dorsal cortex medial pyramidal cell', u'count': 1},
#  {u'_id': u'Intramuscular interstitial cell of Cajal (ICCIM)', u'count': 1},
#  {u'_id': u'Hermissenda photoreceptor Type A', u'count': 1},
#  {u'_id': u'Aplysia feeding CPG neurons', u'count': 1},
#  {u'_id': u'Spinal cord lamina I neuron', u'count': 1},
#  {u'_id': u'Crab Stomatogastric Ganglion (STG) interneuron 1 (Int1)',
#   u'count': 1},
#  {u'_id': u'Leech pressure (P) mechanosensory neuron', u'count': 1},
#  {u'_id': u'Aplysia cultured neuron', u'count': 1},
#  {u'_id': u'B lymphocyte', u'count': 1},
#  {u'_id': u'Neocortical pyramidal cortical-thalamic cell', u'count': 1},
#  {u'_id': u'Olfactory bulb (accessory) mitral cell', u'count': 1},
#  {u'_id': u'Hippocampus CA3 axo-axonic cells', u'count': 1},
#  {u'_id': u'Fly medulla neuron', u'count': 1},
#  {u'_id': u'Fly lamina neuron', u'count': 1},
#  {u'_id': u'Olfactory bulb main tufted middle cell', u'count': 1},
#  {u'_id': u'Gastrointestinal tract intrinsic sensory neuron', u'count': 1},
#  {u'_id': u'Fly vertical system tangential cell', u'count': 1},
#  {u'_id': u'Crab Stomatogastric Ganglion (STG) Modulatory commissural neuron 1 (MCN1)',
#   u'count': 1},
#  {u'_id': u'Leech heart motor neuron (HE)', u'count': 1},
#  {u'_id': u'Grueneberg ganglion neuron', u'count': 1},
#  {u'_id': u'Nucleus laminaris neuron', u'count': 1},
#  {u'_id': u'Neocortex superficial neurogliaform interneuron', u'count': 1},
#  {u'_id': u'Neocortex deep neurogliaform interneuron', u'count': 1},
#  {u'_id': u'Crayfish motor neuron', u'count': 1},
#  {u'_id': u'Substantia nigra pars reticulata principal cell', u'count': 1},
#  {u'_id': u'Neocortical pyramidal tract cortical-spinal cell', u'count': 1},
#  {u'_id': u'Olfactory cortex anterior interneuron superficial layer',
#   u'count': 1},
#  {u'_id': u'Dorsal Root Ganglion cell: cold sensing', u'count': 1},
#  {u'_id': u'Locus Coeruleus neuron', u'count': 1},
#  {u'_id': u'Inferior olive neuron', u'count': 1},
#  {u'_id': u'Lateral Superior Olive (LSO) cell', u'count': 1},
#  {u'_id': u'Spinal cord renshaw cell', u'count': 1},
#  {u'_id': u'Olfactory bulb main juxtaglomerular cell', u'count': 1},
#  {u'_id': u'Crayfish identified nonspiking interneuron', u'count': 1},
#  {u'_id': u'Hippocampus septum medial GABAergic neuron', u'count': 1},
#  {u'_id': u'Vibrissa motor plant', u'count': 1},
#  {u'_id': u'C elegans uterine-vulval cell (uv1)', u'count': 1},
#  {u'_id': u'Cochlear nucleus octopus cell', u'count': 1},
#  {u'_id': u'Myenteric interstitial cell of Cajal (ICCMY)', u'count': 1},
#  {u'_id': u'Hippocampus CA1 stratum radiatum interneuron', u'count': 1},
#  {u'_id': u'Neocortex spiking irregular interneuron', u'count': 1},
#  {u'_id': u'Thalamus DLM projection neuron', u'count': 1},
#  {u'_id': u'C elegans Hermaphrodite-Specific neuron (HSN)', u'count': 1},
#  {u'_id': u'Spinal cord sympathetic preganglionic neuron', u'count': 1},
#  {u'_id': u'Pinsky-Rinzel CA1/3 pyramidal cell ', u'count': 1},
#  {u'_id': u'Neocortical pyramidal intra-telencephalic cell', u'count': 1},
#  {u'_id': u'Hippocampus CA3 stratum radiatum lacunosum-moleculare interneuron',
#   u'count': 1},
#  {u'_id': u'Hippocampus CA1 stratum oriens lacunosum-moleculare interneuron ',
#   u'count': 1},
#  {u'_id': u'Helix pacemaker bursting neuron (RPa1)', u'count': 1},
#  {u'_id': u'Arteriolar network', u'count': 1},
#  {u'_id': u'Leech Retzius neuron', u'count': 1},
#  {u'_id': u'Drosophila antennal lobe DM1 projection neuron', u'count': 1},
#  {u'_id': u'C elegans VC motor neuron', u'count': 1},
#  {u'_id': u'Stick insect nonspiking interneuron', u'count': 1},
#  {u'_id': u'Turtle dorsal cortex lateral pyramidal cell', u'count': 1},
#  {u'_id': u'Leech C interneuron', u'count': 1},
#  {u'_id': u'Spinal cord Ia interneuron', u'count': 1},
#  {u'_id': u'Spinal cord motor neuron fast fatiguing', u'count': 1},
#  {u'_id': u'Fly lobular plate vertical system cell', u'count': 1},
#  {u'_id': u'Aplysia B31/B32 neuron', u'count': 1},
#  {u'_id': u'Turtle dorsal cortex stellate cell', u'count': 1},
#  {u'_id': u'Abstract Hindmarsh-Rose neuron', u'count': 1},
#  {u'_id': u'Depressor scutorum rostralis muscle cell', u'count': 1},
#  {u'_id': u'Superior paraolivary nucleus neuron', u'count': 1},
#  {u'_id': u'Abstract theta neuron', u'count': 1},
#  {u'_id': u'Spinal cord Ib interneuron', u'count': 1},
#  {u'_id': u'Spinal cord motor neuron fatigue resistant', u'count': 1},
#  {u'_id': u'Hippocampus dissociated neuron', u'count': 1},
#  {u'_id': u'Olfactory cortex anterior interneuron deep layer', u'count': 1},
#  {u'_id': u'Electric fish P- and T-type primary afferent fibers', u'count': 1},
#  {u'_id': u'Olfactory bulb short axon cell', u'count': 1},
#  {u'_id': u'Neocortex dissociated cultured nerve cell', u'count': 1}]

# %% [markdown]
# Find the model titles (not paper titles) for models that (1) involve a Hippocampus CA3 pyramidal cell, and (2) have an associated reference where one of the authors is "Migliore M".

# %%
myquery = [
            
    
            {'$lookup': 
                {'from' : 'models',
                 'localField' : '_id',
                 'foreignField' : 'references',
                 'as' : 'matched'}
            },
    
            {'$unwind': '$matched'},
    
            
            {'$match': {'authors' : 'Migliore M', 'matched.celltypes' : 'Hippocampus CA3 pyramidal cell'}},
            
            {'$project': {'authors':1, 'matched.title':1}} 
        ]

for doc in (papers.aggregate(myquery)):
    pprint.pprint (doc)
# Out:
# {u'_id': 4307,
#  u'authors': [u'Migliore M',
#               u'Cook EP',
#               u'Jaffe DB',
#               u'Johnston D',
#               u'Turner DA'],
#  u'matched': {u'title': u'CA3 Pyramidal Neuron (Migliore et al 1995)'}}
# {u'_id': 20013,
#  u'authors': [u'Migliore M', u'Lazarewicz MT', u'Ascoli GA'],
#  u'matched': {u'title': u'CA3 pyramidal neuron (Lazarewicz et al 2002)'}}
# {u'_id': 105513,
#  u'authors': [u'Migliore M',
#               u'Jaffe DB',
#               u'Ascoli GA',
#               u'Hemond P',
#               u'Boley A'],
#  u'matched': {u'title': u'CA3 pyramidal neuron: firing properties (Hemond et al. 2008)'}}
# {u'_id': 118099,
#  u'authors': [u'Migliore M', u'Jaffe DB', u'Ascoli GA', u'Hemond P'],
#  u'matched': {u'title': u'Ca3 pyramidal neuron: membrane response near rest (Hemond et al. 2009)'}}
# {u'_id': 126815,
#  u'authors': [u'Migliore M',
#               u'Cherubini E',
#               u'Sivakumaran S',
#               u'Safiulina VF',
#               u'Caiati MD',
#               u'Bisson G'],
#  u'matched': {u'title': u'CA3 pyramidal neuron (Safiulina et al. 2010)'}}
# {u'_id': 137261,
#  u'authors': [u'Migliore M',
#               u'Barrionuevo G',
#               u'Ascoli GA',
#               u'Baker JL',
#               u'Perez-Rosello T'],
#  u'matched': {u'title': u'A model of unitary responses from A/C and PP synapses in CA3 pyramidal cells (Baker et al. 2010)'}}

# %% [markdown]
# Find all the authors who were on a paper associated with a model that involved a Hippocampus CA3 pyramidal cell. Sort them in alphabetical order; give this list and state its length.

# %%
myquery2 = [
            {'$lookup': 
                {'from' : 'papers',
                 'localField' : 'references',
                 'foreignField' : '_id',
                 'as' : 'matched2'}},
    
            {'$unwind': '$matched2'},
    
            {'$match': {'celltypes' : 'Hippocampus CA3 pyramidal cell'}},
    
            {'$project': {'matched2.authors':1}},
    
            {'$sort' : { 'matched2.authors' : 1} }
        ]

for doc in  (models.aggregate(myquery2)):
    pprint.pprint (doc)
# Out:
# {u'_id': 129067, u'matched2': {}}
# {u'_id': 148035, u'matched2': {}}
# {u'_id': 151282, u'matched2': {}}
# {u'_id': 137505, u'matched2': {u'authors': u'Murray TA'}}
# {u'_id': 87216,
#  u'matched2': {u'authors': [u'Bi GQ',
#                             u'Wang YT',
#                             u'Gerkin RC',
#                             u'Nauen DW',
#                             u'Lau PM']}}
# {u'_id': 146499, u'matched2': {u'authors': [u'Campbell SA', u'Nicola W']}}
# {u'_id': 147867, u'matched2': {u'authors': [u'Chattarji S', u'Narayanan R']}}
# {u'_id': 147756,
#  u'matched2': {u'authors': [u'Chattarji S', u'Narayanan R', u'Narayan A']}}
# {u'_id': 142104,
#  u'matched2': {u'authors': [u'Ditto WL',
#                             u'Zhou J',
#                             u'Talathi SS',
#                             u'Carney PR',
#                             u'Stanley DA',
#                             u'Parekh MB',
#                             u'Cordiner DJ',
#                             u'Mareci TH']}}
# {u'_id': 168314,
#  u'matched2': {u'authors': [u'Franklin CC', u'Nair SS', u'Hummos A']}}
# {u'_id': 143148,
#  u'matched2': {u'authors': [u'Gerstner W',
#                             u'Petersen CC',
#                             u'Naud R',
#                             u'Avermann M',
#                             u'Mensi S',
#                             u'Pozzorini C']}}
# {u'_id': 138421,
#  u'matched2': {u'authors': [u'Heinemann U',
#                             u'Traub RD',
#                             u'Monyer H',
#                             u'Whittington MA',
#                             u'Kopell NJ',
#                             u'Gloveli T',
#                             u'Rotstein HG',
#                             u'Dugladze T']}}
# {u'_id': 168874,
#  u'matched2': {u'authors': [u'Hines ML',
#                             u'Lytton WW',
#                             u'Fall CP',
#                             u'Neymotin SA',
#                             u'McDougal RA',
#                             u'Sherif MA']}}
# {u'_id': 138421,
#  u'matched2': {u'authors': [u'Kopell N',
#                             u'Borgers C',
#                             u'Pervouchine D',
#                             u'Tort AB',
#                             u'Malerba P']}}
# {u'_id': 138421,
#  u'matched2': {u'authors': [u'Kopell NJ',
#                             u'Gloveli T',
#                             u'Rotstein HG',
#                             u'Dugladze T',
#                             u'Tort AB']}}
# {u'_id': 184139,
#  u'matched2': {u'authors': [u'Lee SH',
#                             u'Kim S',
#                             u'Lee KH',
#                             u'Bae YC',
#                             u'Ho WK',
#                             u'Hyun JH',
#                             u'Eom K',
#                             u'Bae JY',
#                             u'Kim MH']}}
# {u'_id': 139421,
#  u'matched2': {u'authors': [u'Lytton WW',
#                             u'Contreras D',
#                             u'Finkel LH',
#                             u'Lazarewicz MT',
#                             u'Neymotin SA',
#                             u'Sherif M']}}
# {u'_id': 137259,
#  u'matched2': {u'authors': [u'Migliore M',
#                             u'Barrionuevo G',
#                             u'Ascoli GA',
#                             u'Baker JL',
#                             u'Perez-Rosello T']}}
# {u'_id': 126814,
#  u'matched2': {u'authors': [u'Migliore M',
#                             u'Cherubini E',
#                             u'Sivakumaran S',
#                             u'Safiulina VF',
#                             u'Caiati MD',
#                             u'Bisson G']}}
# {u'_id': 3263,
#  u'matched2': {u'authors': [u'Migliore M',
#                             u'Cook EP',
#                             u'Jaffe DB',
#                             u'Johnston D',
#                             u'Turner DA']}}
# {u'_id': 118098,
#  u'matched2': {u'authors': [u'Migliore M',
#                             u'Jaffe DB',
#                             u'Ascoli GA',
#                             u'Hemond P']}}
# {u'_id': 101629,
#  u'matched2': {u'authors': [u'Migliore M',
#                             u'Jaffe DB',
#                             u'Ascoli GA',
#                             u'Hemond P',
#                             u'Boley A']}}
# {u'_id': 20007,
#  u'matched2': {u'authors': [u'Migliore M', u'Lazarewicz MT', u'Ascoli GA']}}
# {u'_id': 120907, u'matched2': {u'authors': [u'Munro E', u'Borgers C']}}
# {u'_id': 186768,
#  u'matched2': {u'authors': [u'Neymotin SA', u'Sanjay M', u'Krothapalli SB']}}
# {u'_id': 98003, u'matched2': {u'authors': [u'Olds JL', u'Baker JL']}}
# {u'_id': 150288, u'matched2': {u'authors': [u'Pare D', u'Kim D', u'Nair SS']}}
# {u'_id': 181967, u'matched2': {u'authors': [u'Poirazi P', u'Cutsuridis V']}}
# {u'_id': 35358, u'matched2': {u'authors': [u'Rinzel J', u'Pinsky PF']}}
# {u'_id': 35358, u'matched2': {u'authors': [u'Rinzel J', u'Pinsky PF']}}
# {u'_id': 7907,
#  u'matched2': {u'authors': [u'Roth A', u'Hausser M', u'Vetter P']}}
# {u'_id': 185512,
#  u'matched2': {u'authors': [u'So P', u'Barreto E', u'Reznik RI', u'Sander E']}}
# {u'_id': 135902,
#  u'matched2': {u'authors': [u'Stacey WC', u'Lazarewicz MT', u'Litt B']}}
# {u'_id': 135903,
#  u'matched2': {u'authors': [u'Stacey WC', u'Litt B', u'Krieger A']}}
# {u'_id': 189088,
#  u'matched2': {u'authors': [u'Tsaneva-Atanasova KT',
#                             u'Atherton LA',
#                             u'Prince LY']}}
# {u'_id': 84606,
#  u'matched2': {u'authors': [u'Wu SN', u'Huang CW', u'Huang CC']}}
# {u'_id': 87762,
#  u'matched2': {u'authors': [u'Wu SN',
#                             u'Tsai JJ',
#                             u'Cheng JT',
#                             u'Huang CW',
#                             u'Huang CC']}}
# {u'_id': 114337, u'matched2': {u'authors': [u'Xu J', u'Clancy CE']}}

# %% [markdown]
# <h1>Modify the database</h1>

# %% [markdown]
# Rename the Hippocampus CA1 pyramidal cell to be the Hippocampus CA1 pyramidal neuron. (Note: here we're using CA1 instead of CA3.) Make sure that this is consistent across all documents in the models collection.

# %%
models.update_many({'celltypes': 'Hippocampus CA1 pyramidal cell'},
                  {'$set': {'celltypes.$': 'Hippocampus CA1 pyramidal neuron'}}
)

# %% [markdown]
# Add a new entry (make up the data, but keep it appropriate) to the models collection. Associate it with two references, one that already exists and one that you also add to the papers collection.

# %%
models.insert_one({
                  u'_id': 555555,
                  u'title': 'NZT Responsive Neuron',
                  u'text': 'Neurons responsive to NZT from the movie limitless',
                  u'genes': '[]',
                  u'channels': [u'I L high threshold', u'I h', u'I K,Ca', u'I Calcium',u'I_HERG'],
                  u'modelconcepts': [u'Ion Channel Kinetics', u'Oscillations', u'Calcium dynamics'],
                 u'modeltype': [u'Neuron or other electrically excitable cell'],
                 u'receptors': [],
                 u'references': [100604,666666],
                 u'simenvironment': [u'C or C++ program', u'FORTRAN'],
              })
# Out:
# ---------------------------------------------------------------------------
# DuplicateKeyError                         Traceback (most recent call last)
# <ipython-input-52-b1b91ade7563> in <module>()
#       9                  u'receptors': [],
#      10                  u'references': [100604,666666],
# ---> 11                  u'simenvironment': [u'C or C++ program', u'FORTRAN'],
#      12               })
#      13
#
# //anaconda/lib/python2.7/site-packages/pymongo/collection.pyc in insert_one(self, document, bypass_document_validation)
#     628             return InsertOneResult(
#     629                 self._insert(sock_info, document,
# --> 630                              bypass_doc_val=bypass_document_validation),
#     631                 self.write_concern.acknowledged)
#     632
#
# //anaconda/lib/python2.7/site-packages/pymongo/collection.pyc in _insert(self, sock_info, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val)
#     533             return self._insert_one(
#     534                 sock_info, docs, ordered,
# --> 535                 check_keys, manipulate, write_concern, op_id, bypass_doc_val)
#     536
#     537         ids = []
#
# //anaconda/lib/python2.7/site-packages/pymongo/collection.pyc in _insert_one(self, sock_info, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val)
#     515                 codec_options=self.__write_response_codec_options,
#     516                 check_keys=check_keys)
# --> 517             _check_write_command_response([(0, result)])
#     518         else:
#     519             # Legacy OP_INSERT.
#
# //anaconda/lib/python2.7/site-packages/pymongo/helpers.pyc in _check_write_command_response(results)
#     307             error["index"] += offset
#     308             if error.get("code") == 11000:
# --> 309                 raise DuplicateKeyError(error.get("errmsg"), 11000, error)
#     310             raise WriteError(error.get("errmsg"), error.get("code"), error)
#     311         else:
#
# DuplicateKeyError: E11000 duplicate key error collection: hw1.models index: _id_ dup key: { : 555555 }

# %%
papers.insert_one(
{u'_id': 888888,
 u'authors': [u'Brar RS', u'Hines ML', u'Neild TO'],
 u'doi': u'10.1111/j.1549-8719.2001.tb00156.x',
 u'first_page': u'33',
 u'journal': u'Informatics',
 u'last_page': u'43',
 u'missing_references': u'all done',
 u'month': u'Feb',
 u'pubmed_id': u'19296859',
 u'references': [
                666666,
                4461,
                 4755,
                 4757,
                 4758,
                 4764,
                 4770,
                 4773,
                 4777,
                 4781,
                 4782,
                 4786,
                 4790,
                 4792,
                 4793,
                 4797,
                 4799,
                 4800,
                 4805,
                 4806,
                 4810,
                 4815,
                 4818,
                 4819,
                 4820,
                 4823,
                 4825,
                 17148,
                 17150,
                 17152,
                 17154,
                 86943],
 u'title': u'NZT',
 u'type': u'M',
 u'volume': u'8',
 u'year': u'2001'})
